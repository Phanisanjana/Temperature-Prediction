# %%
import pandas as pd

weather = pd.read_csv("C:\Project_temp\Dataset.csv", index_col="DATE")

# %%
weather
# Out:
#                STATION                    NAME  AWND  DAPR  FMTM  MDPR  PGTM  \
# DATE
# 3/18/2014  US1MOSL0019    FENTON 1.7 SW, MO US   NaN   NaN   NaN   NaN   NaN
# 5/26/2014  US1MOSL0019    FENTON 1.7 SW, MO US   NaN   NaN   NaN   NaN   NaN
# 5/27/2014  US1MOSL0019    FENTON 1.7 SW, MO US   NaN   NaN   NaN   NaN   NaN
# 5/28/2014  US1MOSL0019    FENTON 1.7 SW, MO US   NaN   NaN   NaN   NaN   NaN
# 5/29/2014  US1MOSL0019    FENTON 1.7 SW, MO US   NaN   NaN   NaN   NaN   NaN
# ...                ...                     ...   ...   ...   ...   ...   ...
# 8/27/2023  US1MOSL0062  CONCORD 1.0 SSW, MO US   NaN   NaN   NaN   NaN   NaN
# 9/5/2023   US1MOSL0062  CONCORD 1.0 SSW, MO US   NaN   NaN   NaN   NaN   NaN
# 9/6/2023   US1MOSL0062  CONCORD 1.0 SSW, MO US   NaN   NaN   NaN   NaN   NaN
# 9/12/2023  US1MOSL0062  CONCORD 1.0 SSW, MO US   NaN   NaN   NaN   NaN   NaN
# 9/21/2023  US1MOSL0062  CONCORD 1.0 SSW, MO US   NaN   NaN   NaN   NaN   NaN
#
#            PRCP  SNOW  SNWD  ...  WT09  WT10  WT11  WT13  WT14  WT15  WT16  \
# DATE                         ...
# 3/18/2014  0.00   0.0   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5/26/2014  0.20   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5/27/2014  0.86   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5/28/2014  0.10   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5/29/2014  0.00   0.0   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...         ...   ...   ...  ...   ...   ...   ...   ...   ...   ...   ...
# 8/27/2023  0.79   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9/5/2023   0.20   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9/6/2023   0.24   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9/12/2023  0.05   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9/21/2023  0.03   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#            WT17  WT18  WT22
# DATE
# 3/18/2014   NaN   NaN   NaN
# 5/26/2014   NaN   NaN   NaN
# 5/27/2014   NaN   NaN   NaN
# 5/28/2014   NaN   NaN   NaN
# 5/29/2014   NaN   NaN   NaN
# ...         ...   ...   ...
# 8/27/2023   NaN   NaN   NaN
# 9/5/2023    NaN   NaN   NaN
# 9/6/2023    NaN   NaN   NaN
# 9/12/2023   NaN   NaN   NaN
# 9/21/2023   NaN   NaN   NaN
#
# [109633 rows x 38 columns]

# %%
null_pct = weather.apply(pd.isnull).sum()/weather.shape[0]
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# AWND       0.914852
# DAPR       0.982387
# FMTM       0.996698
# MDPR       0.982423
# PGTM       0.993278
# PRCP       0.023278
# SNOW       0.371822
# SNWD       0.775423
# TAVG       0.966497
# TMAX       0.808662
# TMIN       0.808361
# TOBS       0.891939
# WDF2       0.914852
# WDF5       0.915609
# WESD       0.972454
# WESF       0.962803
# WSF2       0.914852
# WSF5       0.915609
# WT01       0.966306
# WT02       0.996981
# WT03       0.985880
# WT04       0.998896
# WT05       0.999580
# WT06       0.998531
# WT07       0.999982
# WT08       0.987631
# WT09       0.999854
# WT10       0.999982
# WT11       0.999754
# WT13       0.998230
# WT14       0.999279
# WT15       0.999954
# WT16       0.997109
# WT17       0.999927
# WT18       0.999143
# WT22       0.999936
# dtype: float64

# %%
valid_columns = weather.columns[null_pct < .81]

# %%
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
weather = weather[valid_columns].copy()

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#                station                    name  prcp  snow  snwd  tmax  tmin
# DATE
# 3/18/2014  US1MOSL0019    FENTON 1.7 SW, MO US  0.00   0.0   NaN   NaN   NaN
# 5/26/2014  US1MOSL0019    FENTON 1.7 SW, MO US  0.20   NaN   NaN   NaN   NaN
# 5/27/2014  US1MOSL0019    FENTON 1.7 SW, MO US  0.86   NaN   NaN   NaN   NaN
# 5/28/2014  US1MOSL0019    FENTON 1.7 SW, MO US  0.10   NaN   NaN   NaN   NaN
# 5/29/2014  US1MOSL0019    FENTON 1.7 SW, MO US  0.00   0.0   NaN   NaN   NaN
# ...                ...                     ...   ...   ...   ...   ...   ...
# 8/27/2023  US1MOSL0062  CONCORD 1.0 SSW, MO US  0.79   NaN   NaN   NaN   NaN
# 9/5/2023   US1MOSL0062  CONCORD 1.0 SSW, MO US  0.20   NaN   NaN   NaN   NaN
# 9/6/2023   US1MOSL0062  CONCORD 1.0 SSW, MO US  0.24   NaN   NaN   NaN   NaN
# 9/12/2023  US1MOSL0062  CONCORD 1.0 SSW, MO US  0.05   NaN   NaN   NaN   NaN
# 9/21/2023  US1MOSL0062  CONCORD 1.0 SSW, MO US  0.03   NaN   NaN   NaN   NaN
#
# [109633 rows x 7 columns]

# %%
weather = weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# station        0
# name           0
# prcp           0
# snow           0
# snwd        1434
# tmax       28934
# tmin       28934
# dtype: int64

# %%
weather.apply(lambda x: (x == 9999).sum())
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax       float64
# tmin       float64
# dtype: object

# %%
weather.index
# Out:
# Index(['3/18/2014', '5/26/2014', '5/27/2014', '5/28/2014', '5/29/2014',
#        '5/30/2014', '5/31/2014', '6/1/2014', '6/2/2014', '6/3/2014',
#        ...
#        '8/11/2023', '8/13/2023', '8/14/2023', '8/15/2023', '8/26/2023',
#        '8/27/2023', '9/5/2023', '9/6/2023', '9/12/2023', '9/21/2023'],
#       dtype='object', name='DATE', length=109633)

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# DATE
# 2010     511
# 2011    6964
# 2012    7295
# 2013    7664
# 2014    8325
# 2015    8899
# 2016    9053
# 2017    8679
# 2018    8112
# 2019    8585
# 2020    9344
# 2021    9200
# 2022    9828
# 2023    7174
# Name: count, dtype: int64

# %%
weather["snwd"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather["target"] = weather.shift(-1)["tmax"]

# %%
weather
# Out:
#                 station                    name  prcp  snow  snwd  tmax  tmin  \
# DATE
# 2014-03-18  US1MOSL0019    FENTON 1.7 SW, MO US  0.00   0.0   NaN   NaN   NaN
# 2014-05-26  US1MOSL0019    FENTON 1.7 SW, MO US  0.20   0.0   NaN   NaN   NaN
# 2014-05-27  US1MOSL0019    FENTON 1.7 SW, MO US  0.86   0.0   NaN   NaN   NaN
# 2014-05-28  US1MOSL0019    FENTON 1.7 SW, MO US  0.10   0.0   NaN   NaN   NaN
# 2014-05-29  US1MOSL0019    FENTON 1.7 SW, MO US  0.00   0.0   NaN   NaN   NaN
# ...                 ...                     ...   ...   ...   ...   ...   ...
# 2023-08-27  US1MOSL0062  CONCORD 1.0 SSW, MO US  0.79   0.0   1.5  85.0  62.0
# 2023-09-05  US1MOSL0062  CONCORD 1.0 SSW, MO US  0.20   0.0   1.5  85.0  62.0
# 2023-09-06  US1MOSL0062  CONCORD 1.0 SSW, MO US  0.24   0.0   1.5  85.0  62.0
# 2023-09-12  US1MOSL0062  CONCORD 1.0 SSW, MO US  0.05   0.0   1.5  85.0  62.0
# 2023-09-21  US1MOSL0062  CONCORD 1.0 SSW, MO US  0.03   0.0   1.5  85.0  62.0
#
#             target
# DATE
# 2014-03-18     NaN
# 2014-05-26     NaN
# 2014-05-27     NaN
# 2014-05-28     NaN
# 2014-05-29     NaN
# ...            ...
# 2023-08-27    85.0
# 2023-09-05    85.0
# 2023-09-06    85.0
# 2023-09-12    85.0
# 2023-09-21     NaN
#
# [109633 rows x 8 columns]

# %%
weather = weather.ffill()
weather = weather.fillna(0)

# %%
weather
# Out:
#                 station                    name  prcp  snow  snwd  tmax  tmin  \
# DATE
# 2014-03-18  US1MOSL0019    FENTON 1.7 SW, MO US  0.00   0.0   0.0   0.0   0.0
# 2014-05-26  US1MOSL0019    FENTON 1.7 SW, MO US  0.20   0.0   0.0   0.0   0.0
# 2014-05-27  US1MOSL0019    FENTON 1.7 SW, MO US  0.86   0.0   0.0   0.0   0.0
# 2014-05-28  US1MOSL0019    FENTON 1.7 SW, MO US  0.10   0.0   0.0   0.0   0.0
# 2014-05-29  US1MOSL0019    FENTON 1.7 SW, MO US  0.00   0.0   0.0   0.0   0.0
# ...                 ...                     ...   ...   ...   ...   ...   ...
# 2023-08-27  US1MOSL0062  CONCORD 1.0 SSW, MO US  0.79   0.0   1.5  85.0  62.0
# 2023-09-05  US1MOSL0062  CONCORD 1.0 SSW, MO US  0.20   0.0   1.5  85.0  62.0
# 2023-09-06  US1MOSL0062  CONCORD 1.0 SSW, MO US  0.24   0.0   1.5  85.0  62.0
# 2023-09-12  US1MOSL0062  CONCORD 1.0 SSW, MO US  0.05   0.0   1.5  85.0  62.0
# 2023-09-21  US1MOSL0062  CONCORD 1.0 SSW, MO US  0.03   0.0   1.5  85.0  62.0
#
#             target
# DATE
# 2014-03-18     0.0
# 2014-05-26     0.0
# 2014-05-27     0.0
# 2014-05-28     0.0
# 2014-05-29     0.0
# ...            ...
# 2023-08-27    85.0
# 2023-09-05    85.0
# 2023-09-06    85.0
# 2023-09-12    85.0
# 2023-09-21    85.0
#
# [109633 rows x 8 columns]

# %%
from sklearn.linear_model import Ridge

rr = Ridge(alpha=.1)

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
def backtest(weather, model, predictors, start=3650, step=90):
    all_predictions = []
    
    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(weather, rr, predictors)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 1.7254681526426867

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 2011-01-01    31.0   82.817452  51.817452
# 2023-09-21    38.0   84.477498  46.477498
# 2011-02-08    15.0   58.986277  43.986277
# 2018-01-11    18.0   61.550951  43.550951
# 2011-03-31    92.0   49.734512  42.265488
# ...            ...         ...        ...
# 2023-07-27     0.0    0.000000   0.000000
# 2023-07-28     0.0    0.000000   0.000000
# 2023-07-29     0.0    0.000000   0.000000
# 2023-07-30     0.0    0.000000   0.000000
# 2022-02-10     0.0    0.000000   0.000000
#
# [105983 rows x 3 columns]

# %%
pd.Series(rr.coef_, index=predictors)
# Out:
# prcp   -0.664236
# snow   -0.037721
# snwd    0.006838
# tmax    0.908564
# tmin    0.115538
# dtype: float64

# %%
def pct_diff(old, new):
    return (new - old) / old

def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}_{col}"
    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}_pct"] = pct_diff(weather[label], weather[col])
    return weather
    
rolling_horizons = [3, 14]
for horizon in rolling_horizons:
    for col in ["tmax", "tmin", "prcp"]:
        weather = compute_rolling(weather, horizon, col)

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax", "tmin", "prcp"]:
    weather[f"month_avg_{col}"] = weather.groupby(weather.index.month)[col].transform(expand_mean)
    weather[f"day_avg_{col}"] = weather.groupby(weather.index.day_of_year)[col].transform(expand_mean)

# %%
weather = weather.iloc[14:,:]
weather = weather.fillna(0)

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
mean_squared_error(predictions["actual"], predictions["prediction"])
# Out:
# 16.70496263776558

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 2011-01-01    31.0   82.817452  51.817452
# 2023-09-21    38.0   84.477498  46.477498
# 2011-02-08    15.0   58.986277  43.986277
# 2018-01-11    18.0   61.550951  43.550951
# 2011-03-31    92.0   49.734512  42.265488
# ...            ...         ...        ...
# 2023-07-27     0.0    0.000000   0.000000
# 2023-07-28     0.0    0.000000   0.000000
# 2023-07-29     0.0    0.000000   0.000000
# 2023-07-30     0.0    0.000000   0.000000
# 2022-02-10     0.0    0.000000   0.000000
#
# [105983 rows x 3 columns]

# %%
weather.loc["2014-03-07": "2014-03-17"]
# Out:
#                 station                                           name  prcp  \
# DATE
# 2014-03-07  US1MOSLC007                        ST. LOUIS 5.7 SW, MO US   0.0
# 2014-03-08  US1MOSLC007                        ST. LOUIS 5.7 SW, MO US   0.0
# 2014-03-09  US1MOSLC007                        ST. LOUIS 5.7 SW, MO US   0.0
# 2014-03-10  US1MOSLC007                        ST. LOUIS 5.7 SW, MO US   0.0
# 2014-03-11  US1MOSLC007                        ST. LOUIS 5.7 SW, MO US   0.0
# ...                 ...                                            ...   ...
# 2014-03-13  USW00013994  ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US   0.0
# 2014-03-14  USW00013994  ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US   0.0
# 2014-03-15  USW00013994  ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US   0.0
# 2014-03-16  USW00013994  ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US   0.0
# 2014-03-17  USW00013994  ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US   0.0
#
#             snow  snwd  tmax  tmin  target  rolling_3_tmax  \
# DATE
# 2014-03-07   0.0   0.5   0.0   0.0     0.0        0.000000
# 2014-03-08   0.0   0.5   0.0   0.0     0.0        0.000000
# 2014-03-09   0.0   0.5   0.0   0.0     0.0        0.000000
# 2014-03-10   0.0   0.5   0.0   0.0     0.0        0.000000
# 2014-03-11   0.0   0.5   0.0   0.0     0.0        0.000000
# ...          ...   ...   ...   ...     ...             ...
# 2014-03-13   0.0   0.0  64.0  29.0    69.0       64.666667
# 2014-03-14   0.0   0.0  69.0  42.0    72.0       60.000000
# 2014-03-15   0.0   0.0  72.0  36.0    48.0       68.333333
# 2014-03-16   0.0   0.0  48.0  27.0    49.0       63.000000
# 2014-03-17   0.0   0.0  49.0  20.0    60.0       56.333333
#
#             rolling_3_tmax_pct  ...  rolling_14_tmin  rolling_14_tmin_pct  \
# DATE                            ...
# 2014-03-07            0.000000  ...         0.000000             0.000000
# 2014-03-08            0.000000  ...         0.000000             0.000000
# 2014-03-09            0.000000  ...         0.000000             0.000000
# 2014-03-10            0.000000  ...         0.000000             0.000000
# 2014-03-11            0.000000  ...         0.000000             0.000000
# ...                        ...  ...              ...                  ...
# 2014-03-13           -0.010309  ...        25.642857             0.130919
# 2014-03-14            0.150000  ...        27.285714             0.539267
# 2014-03-15            0.053659  ...        28.142857             0.279188
# 2014-03-16           -0.238095  ...        29.571429            -0.086957
# 2014-03-17           -0.130178  ...        30.714286            -0.348837
#
#             rolling_14_prcp  rolling_14_prcp_pct  month_avg_tmax  \
# DATE
# 2014-03-07         0.030000                 -1.0        0.000000
# 2014-03-08         0.030000                 -1.0        0.000000
# 2014-03-09         0.030000                 -1.0        0.000000
# 2014-03-10         0.030000                 -1.0        0.000000
# 2014-03-11         0.030000                 -1.0        0.000000
# ...                     ...                  ...             ...
# 2014-03-13         0.095714                 -1.0       54.863122
# 2014-03-14         0.095714                 -1.0       54.864721
# 2014-03-15         0.095714                 -1.0       54.866659
# 2014-03-16         0.072857                 -1.0       54.865883
# 2014-03-17         0.072857                 -1.0       54.865219
#
#             day_avg_tmax  month_avg_tmin  day_avg_tmin  month_avg_prcp  \
# DATE
# 2014-03-07      0.000000        0.000000      0.000000        0.132168
# 2014-03-08      0.000000        0.000000      0.000000        0.132072
# 2014-03-09      0.000000        0.000000      0.000000        0.131975
# 2014-03-10      0.000000        0.000000      0.000000        0.131879
# 2014-03-11      0.000000        0.000000      0.000000        0.131782
# ...                  ...             ...           ...             ...
# 2014-03-13     54.473684       39.517308     39.308772        0.143329
# 2014-03-14     54.503571       39.517589     39.567857        0.143313
# 2014-03-15     54.687943       39.517191     39.163121        0.143297
# 2014-03-16     56.139785       39.515775     40.207885        0.143281
# 2014-03-17     55.147482       39.513569     39.654676        0.143264
#
#             day_avg_prcp
# DATE
# 2014-03-07      0.178085
# 2014-03-08      0.012222
# 2014-03-09      0.040000
# 2014-03-10      0.133478
# 2014-03-11      0.180222
# ...                  ...
# 2014-03-13      0.125754
# 2014-03-14      0.237857
# 2014-03-15      0.091348
# 2014-03-16      0.047670
# 2014-03-17      0.109964
#
# [208 rows x 26 columns]

# %%
(predictions["diff"].round().value_counts().sort_index() / predictions.shape[0]).plot()
# Out:
# <Axes: xlabel='diff'>

# %%
predictions
# Out:
#             actual  prediction      diff
# DATE
# 2022-02-10     0.0    0.000000  0.000000
# 2022-02-11     0.0    0.000000  0.000000
# 2022-02-12     0.0    0.000000  0.000000
# 2022-02-13     0.0    0.000000  0.000000
# 2022-02-14     0.0    0.000000  0.000000
# ...            ...         ...       ...
# 2023-08-27    85.0   84.365537  0.634463
# 2023-09-05    85.0   84.757437  0.242563
# 2023-09-06    85.0   84.730867  0.269133
# 2023-09-12    85.0   84.857072  0.142928
# 2023-09-21    85.0   84.870357  0.129643
#
# [105983 rows x 3 columns]
